# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('rules.csv', header=None)

# %%
rules = data.apply(lambda x : (x[2]> 0.01 and  x[3] > 0.01), axis=1)

# %%
sum(rules)
# Out:
# 426

# %%
data
# Out:
#                           0                      1         2         3
# 0     Instant food products               UHT-milk  0.000407  0.050633
# 1     Instant food products          baking powder  0.000305  0.037975
# 2     Instant food products                   beef  0.000813  0.101266
# 3     Instant food products                berries  0.000305  0.037975
# 4     Instant food products              beverages  0.000407  0.050633
# 5     Instant food products           bottled beer  0.000610  0.075949
# 6     Instant food products          bottled water  0.001017  0.126582
# 7     Instant food products            brown bread  0.000712  0.088608
# 8     Instant food products                 butter  0.001220  0.151899
# 9     Instant food products               cake bar  0.000102  0.012658
# 10    Instant food products                candles  0.000203  0.025316
# 11    Instant food products                  candy  0.000203  0.025316
# ...
